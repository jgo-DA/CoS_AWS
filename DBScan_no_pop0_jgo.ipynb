# %% [markdown]
# # DBScan Hyperparameter search on dataset without popularity = 0

# %% [markdown]
# This iteration reflects that the dataset has been split into two entries with popularity > 0 and entries with popularity = 0. These two datasets have been saved as csv files on the S§ bucket and will be used in this notebook.

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.cluster import DBSCAN

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Hyperparameter scanning

# %%
# Load the dataset from csv file.
X = pd.read_csv('s3://flutz-bucket/spotify/no_pop0_train_encoded.csv', sep=",", header=0, index_col=0)
X.head()
# Out:
#                         popularity  danceability  energy       key  loudness  \
# track_id
# 2b8fOow8UzyDFAE27YhOZM    1.000000         0.764   0.320  1.000000  0.803915
# 21jGcNKet2qwijlDFuPiPb    0.989899         0.695   0.762  0.000000  0.882646
# 3eekarcy7kvN4yt5ZFzltW    0.979798         0.598   0.427  0.636364  0.770934
# 3ZCTVFBt2Brf31RLEnCkWJ    0.979798         0.704   0.225  0.545455  0.650250
# 2XU0oxnq2qxCpomAAuJY8K    0.979798         0.824   0.588  0.545455  0.821074
#
#                         mode  speechiness  acousticness  instrumentalness  \
# track_id
# 2b8fOow8UzyDFAE27YhOZM     1       0.0546        0.8370          0.000000
# 21jGcNKet2qwijlDFuPiPb     1       0.0395        0.1920          0.002440
# 3eekarcy7kvN4yt5ZFzltW     0       0.0317        0.0546          0.000006
# 3ZCTVFBt2Brf31RLEnCkWJ     0       0.0994        0.9020          0.657000
# 2XU0oxnq2qxCpomAAuJY8K     0       0.0924        0.6920          0.000104
#
#                         liveness  valence     tempo  duration_ms  \
# track_id
# 2b8fOow8UzyDFAE27YhOZM    0.0822   0.5750  0.385677     0.116732
# 21jGcNKet2qwijlDFuPiPb    0.0863   0.5530  0.508657     0.134207
# 3eekarcy7kvN4yt5ZFzltW    0.2100   0.0605  0.324024     0.107407
# 3ZCTVFBt2Brf31RLEnCkWJ    0.1060   0.2430  0.508504     0.154631
# 2XU0oxnq2qxCpomAAuJY8K    0.1490   0.5130  0.415372     0.130250
#
#                         time_signature
# track_id
# 2b8fOow8UzyDFAE27YhOZM             0.8
# 21jGcNKet2qwijlDFuPiPb             0.8
# 3eekarcy7kvN4yt5ZFzltW             0.8
# 3ZCTVFBt2Brf31RLEnCkWJ             0.8
# 2XU0oxnq2qxCpomAAuJY8K             0.8

# %%
# %%time
#Take 1
print('Running a series of DBSCANs to find the best fitting parameters - eps between 0.1 and 0.4.')

clusters_last = []
for EPS in np.arange(0.1, 0.41, 0.1):
  for Min_Samples in range(3, 21):   # range of values for minimum number of samples - between 3 and 20
    dbscan = DBSCAN(eps=EPS, min_samples=Min_Samples)
    pred_dbscan = dbscan.fit_predict(X)

    clusters_this = [*zip(*np.unique(pred_dbscan, return_counts=True))]
    if (clusters_this == clusters_last): print(end='.')
    else: clusters_last = clusters_this; \
      print(f'\nDBSCAN(eps={dbscan.eps:0.1f}, min_samples={dbscan.min_samples:2}):',
        f'Found {max(pred_dbscan) + 1 :2} cluster' + ('s,' if max(pred_dbscan) else ', '),
# DBSCAN(eps=0.3, min_samples= 8): Found 18 clusters, noise=20.51%, cluster_sizes= [(-1, 3013), (0, 6201), (1, 3696), (2, 1220), (3, 161), (4, 23), (5, 14), (6, 8), (7, 18), (8, 12), (9, 8), (10, 167), (11, 78), (12, 27), (13, 7), (14, 14), (15, 10), (16, 9), (17, 2)]
# DBSCAN(eps=0.3, min_samples= 9): Found 16 clusters, noise=21.63%, cluster_sizes= [(-1, 3177), (0, 6143), (1, 3660), (2, 1199), (3, 160), (4, 19), (5, 8), (6, 14), (7, 164), (8, 9), (9, 9), (10, 73), (11, 8), (12, 15), (13, 12), (14, 9), (15, 9)]
# DBSCAN(eps=0.3, min_samples=10): Found 12 clusters, noise=22.96%, cluster_sizes= [(-1, 3372), (0, 5768), (1, 3622), (2, 1165), (3, 160), (4, 10), (5, 11), (6, 157), (7, 324), (8, 17), (9, 63), (10, 10), (11, 9)]
# DBSCAN(eps=0.3, min_samples=11): Found 11 clusters, noise=24.01%, cluster_sizes= [(-1, 3526), (0, 5720), (1, 3577), (2, 1141), (3, 158), (4, 11), (5, 12), (6, 11), (7, 137), (8, 322), (9, 17), (10, 56)]
# DBSCAN(eps=0.3, min_samples=12): Found 11 clusters, noise=24.90%, cluster_sizes= [(-1, 3658), (0, 3544), (1, 5676), (2, 1110), (3, 152), (4, 11), (5, 10), (6, 134), (7, 321), (8, 17), (9, 46), (10, 9)]
# DBSCAN(eps=0.3, min_samples=13): Found  9 clusters, noise=25.68%, cluster_sizes= [(-1, 3772), (0, 3517), (1, 5650), (2, 1088), (3, 149), (4, 11), (5, 10), (6, 319), (7, 127), (8, 45)]
# DBSCAN(eps=0.3, min_samples=14): Found  9 clusters, noise=26.55%, cluster_sizes= [(-1, 3899), (0, 3486), (1, 5550), (2, 1070), (3, 141), (4, 9), (5, 52), (6, 316), (7, 124), (8, 41)]
# DBSCAN(eps=0.3, min_samples=15): Found  9 clusters, noise=27.19%, cluster_sizes= [(-1, 3993), (0, 3468), (1, 5515), (2, 1054), (3, 137), (4, 26), (5, 21), (6, 314), (7, 119), (8, 41)]
# DBSCAN(eps=0.3, min_samples=16): Found 10 clusters, noise=27.83%, cluster_sizes= [(-1, 4088), (0, 3438), (1, 5479), (2, 1046), (3, 90), (4, 39), (5, 25), (6, 21), (7, 312), (8, 109), (9, 41)]
# DBSCAN(eps=0.3, min_samples=17): Found 11 clusters, noise=28.70%, cluster_sizes= [(-1, 4215), (0, 3397), (1, 5352), (2, 1035), (3, 77), (4, 40), (5, 78), (6, 25), (7, 19), (8, 310), (9, 104), (10, 36)]
# DBSCAN(eps=0.3, min_samples=18): Found 12 clusters, noise=29.34%, cluster_sizes= [(-1, 4310), (0, 3372), (1, 5333), (2, 378), (3, 77), (4, 40), (5, 76), (6, 18), (7, 20), (8, 629), (9, 303), (10, 99), (11, 33)]
# DBSCAN(eps=0.3, min_samples=19): Found 11 clusters, noise=30.06%, cluster_sizes= [(-1, 4415), (0, 3344), (1, 5303), (2, 371), (3, 70), (4, 38), (5, 75), (6, 20), (7, 626), (8, 300), (9, 94), (10, 32)]
# DBSCAN(eps=0.3, min_samples=20): Found 11 clusters, noise=30.68%, cluster_sizes= [(-1, 4506), (0, 3313), (1, 5276), (2, 366), (3, 68), (4, 35), (5, 75), (6, 20), (7, 612), (8, 291), (9, 94), (10, 32)]
# DBSCAN(eps=0.4, min_samples= 3): Found 24 clusters, noise= 3.19%, cluster_sizes= [(-1, 468), (0, 8866), (1, 5209), (2, 11), (3, 5), (4, 9), (5, 6), (6, 9), (7, 4), (8, 4), (9, 4), (10, 6), (11, 3), (12, 3), (13, 3), (14, 19), (15, 19), (16, 4), (17, 3), (18, 3), (19, 17), (20, 3), (21, 3), (22, 3), (23, 4)]
# DBSCAN(eps=0.4, min_samples= 4): Found 13 clusters, noise= 3.62%, cluster_sizes= [(-1, 531), (0, 8857), (1, 5196), (2, 11), (3, 5), (4, 9), (5, 8), (6, 4), (7, 4), (8, 5), (9, 4), (10, 18), (11, 19), (12, 17)]
# DBSCAN(eps=0.4, min_samples= 5): Found 11 clusters, noise= 3.93%, cluster_sizes= [(-1, 577), (0, 8846), (1, 5174), (2, 11), (3, 5), (4, 9), (5, 6), (6, 4), (7, 5), (8, 16), (9, 17), (10, 18)]
# DBSCAN(eps=0.4, min_samples= 6): Found  8 clusters, noise= 4.19%, cluster_sizes= [(-1, 616), (0, 8832), (1, 5165), (2, 11), (3, 9), (4, 6), (5, 14), (6, 17), (7, 18)]
# DBSCAN(eps=0.4, min_samples= 7): Found  8 clusters, noise= 4.51%, cluster_sizes= [(-1, 662), (0, 8808), (1, 4645), (2, 510), (3, 9), (4, 10), (5, 16), (6, 15), (7, 13)]
# DBSCAN(eps=0.4, min_samples= 8): Found  9 clusters, noise= 4.78%, cluster_sizes= [(-1, 702), (0, 8784), (1, 4634), (2, 500), (3, 9), (4, 9), (5, 9), (6, 15), (7, 13), (8, 13)]
# DBSCAN(eps=0.4, min_samples= 9): Found  9 clusters, noise= 5.15%, cluster_sizes= [(-1, 757), (0, 8773), (1, 4603), (2, 494), (3, 12), (4, 9), (5, 6), (6, 13), (7, 12), (8, 9)]
# DBSCAN(eps=0.4, min_samples=10): Found  5 clusters, noise= 5.72%, cluster_sizes= [(-1, 840), (0, 8754), (1, 4582), (2, 491), (3, 10), (4, 11)]
# DBSCAN(eps=0.4, min_samples=11): Found  6 clusters, noise= 5.94%, cluster_sizes= [(-1, 873), (0, 8734), (1, 4554), (2, 489), (3, 10), (4, 17), (5, 11)]
# DBSCAN(eps=0.4, min_samples=12): Found  4 clusters, noise= 6.36%, cluster_sizes= [(-1, 934), (0, 8716), (1, 4543), (2, 478), (3, 17)]
# DBSCAN(eps=0.4, min_samples=13): Found  4 clusters, noise= 6.57%, cluster_sizes= [(-1, 965), (0, 8698), (1, 4538), (2, 470), (3, 17)]
# DBSCAN(eps=0.4, min_samples=14): Found  3 clusters, noise= 6.87%, cluster_sizes= [(-1, 1009), (0, 8686), (1, 4532), (2, 461)]
# DBSCAN(eps=0.4, min_samples=15): Found  4 clusters, noise= 7.05%, cluster_sizes= [(-1, 1036), (0, 8673), (1, 4495), (2, 457), (3, 27)]
# DBSCAN(eps=0.4, min_samples=16): Found  4 clusters, noise= 7.28%, cluster_sizes= [(-1, 1070), (0, 8653), (1, 4485), (2, 457), (3, 23)]
# DBSCAN(eps=0.4, min_samples=17): Found  4 clusters, noise= 7.38%, cluster_sizes= [(-1, 1084), (0, 8643), (1, 4481), (2, 457), (3, 23)]
# DBSCAN(eps=0.4, min_samples=18): Found  4 clusters, noise= 7.55%, cluster_sizes= [(-1, 1109), (0, 8635), (1, 4478), (2, 450), (3, 16)]
# DBSCAN(eps=0.4, min_samples=19): Found  4 clusters, noise= 7.85%, cluster_sizes= [(-1, 1153), (0, 8604), (1, 4469), (2, 446), (3, 16)]
# DBSCAN(eps=0.4, min_samples=20): Found  4 clusters, noise= 8.12%, cluster_sizes= [(-1, 1193), (0, 8568), (1, 4466), (2, 443), (3, 18)]CPU times: user 2min 25s, sys: 79.5 ms, total: 2min 25s
# Wall time: 2min 25s

# %%
# %%time
#Take 2
print('Running a series of DBSCANs to find the best fitting parameters - eps between 0.5 and 0.8.')

clusters_last = []
for EPS in np.arange(0.5, 0.81, 0.1):
  for Min_Samples in range(3, 21):   # range of values for minimum number of samples - between 3 and 20
    dbscan = DBSCAN(eps=EPS, min_samples=Min_Samples)
    pred_dbscan = dbscan.fit_predict(X)

    clusters_this = [*zip(*np.unique(pred_dbscan, return_counts=True))]
    if (clusters_this == clusters_last): print(end='.')
    else: clusters_last = clusters_this; \
      print(f'\nDBSCAN(eps={dbscan.eps:0.1f}, min_samples={dbscan.min_samples:2}):',
        f'Found {max(pred_dbscan) + 1 :2} cluster' + ('s,' if max(pred_dbscan) else ', '),
        f'noise={len(pred_dbscan[pred_dbscan==-1]) / len(X) :6.2%},',
          'cluster_sizes=', clusters_this, end='')
# Out:
# Running a series of DBSCANs to find the best fitting parameters - eps between 0.5 and 0.8.
#
# DBSCAN(eps=0.5, min_samples= 3): Found 12 clusters, noise= 0.87%, cluster_sizes= [(-1, 128), (0, 9138), (1, 5385), (2, 6), (3, 3), (4, 3), (5, 3), (6, 5), (7, 4), (8, 3), (9, 3), (10, 3), (11, 4)]
# DBSCAN(eps=0.5, min_samples= 4): Found  5 clusters, noise= 1.05%, cluster_sizes= [(-1, 154), (0, 9136), (1, 5383), (2, 6), (3, 5), (4, 4)]
# DBSCAN(eps=0.5, min_samples= 5): Found  2 clusters, noise= 1.20%, cluster_sizes= [(-1, 176), (0, 9134), (1, 5378)]
# DBSCAN(eps=0.5, min_samples= 6): Found  2 clusters, noise= 1.25%, cluster_sizes= [(-1, 183), (0, 9133), (1, 5372)]
# DBSCAN(eps=0.5, min_samples= 7): Found  2 clusters, noise= 1.30%, cluster_sizes= [(-1, 191), (0, 9129), (1, 5368)]
# DBSCAN(eps=0.5, min_samples= 8): Found  2 clusters, noise= 1.38%, cluster_sizes= [(-1, 202), (0, 9118), (1, 5368)]
# DBSCAN(eps=0.5, min_samples= 9): Found  2 clusters, noise= 1.41%, cluster_sizes= [(-1, 207), (0, 9117), (1, 5364)]
# DBSCAN(eps=0.5, min_samples=10): Found  2 clusters, noise= 1.44%, cluster_sizes= [(-1, 212), (0, 9113), (1, 5363)]
# DBSCAN(eps=0.5, min_samples=11): Found  3 clusters, noise= 1.48%, cluster_sizes= [(-1, 218), (0, 9099), (1, 5360), (2, 11)]
# DBSCAN(eps=0.5, min_samples=12): Found  2 clusters, noise= 1.63%, cluster_sizes= [(-1, 239), (0, 9091), (1, 5358)]
# DBSCAN(eps=0.5, min_samples=13): Found  2 clusters, noise= 1.71%, cluster_sizes= [(-1, 251), (0, 9084), (1, 5353)]
# DBSCAN(eps=0.5, min_samples=14): Found  2 clusters, noise= 1.73%, cluster_sizes= [(-1, 254), (0, 9083), (1, 5351)]
# DBSCAN(eps=0.5, min_samples=15): Found  2 clusters, noise= 1.74%, cluster_sizes= [(-1, 256), (0, 9083), (1, 5349)]
# DBSCAN(eps=0.5, min_samples=16): Found  2 clusters, noise= 1.77%, cluster_sizes= [(-1, 260), (0, 9083), (1, 5345)]
# DBSCAN(eps=0.5, min_samples=17): Found  2 clusters, noise= 1.85%, cluster_sizes= [(-1, 272), (0, 9078), (1, 5338)]
# DBSCAN(eps=0.5, min_samples=18): Found  2 clusters, noise= 1.90%, cluster_sizes= [(-1, 279), (0, 9076), (1, 5333)]
# DBSCAN(eps=0.5, min_samples=19): Found  2 clusters, noise= 1.96%, cluster_sizes= [(-1, 288), (0, 9072), (1, 5328)]
# DBSCAN(eps=0.5, min_samples=20): Found  2 clusters, noise= 2.06%, cluster_sizes= [(-1, 302), (0, 9069), (1, 5317)]
# DBSCAN(eps=0.6, min_samples= 3): Found  7 clusters, noise= 0.26%, cluster_sizes= [(-1, 38), (0, 9195), (1, 5434), (2, 5), (3, 3), (4, 3), (5, 5), (6, 5)]
# DBSCAN(eps=0.6, min_samples= 4): Found  4 clusters, noise= 0.36%, cluster_sizes= [(-1, 53), (0, 9195), (1, 5431), (2, 4), (3, 5)]
# DBSCAN(eps=0.6, min_samples= 5): Found  4 clusters, noise= 0.43%, cluster_sizes= [(-1, 63), (0, 9184), (1, 5430), (2, 6), (3, 5)]
# DBSCAN(eps=0.6, min_samples= 6): Found  3 clusters, noise= 0.50%, cluster_sizes= [(-1, 74), (0, 9179), (1, 5429), (2, 6)]
# DBSCAN(eps=0.6, min_samples= 7): Found  3 clusters, noise= 0.51%, cluster_sizes= [(-1, 75), (0, 9179), (1, 5428), (2, 6)]
# DBSCAN(eps=0.6, min_samples= 8): Found  2 clusters, noise= 0.57%, cluster_sizes= [(-1, 83), (0, 9177), (1, 5428)]
# DBSCAN(eps=0.6, min_samples= 9): Found  2 clusters, noise= 0.57%, cluster_sizes= [(-1, 84), (0, 9177), (1, 5427)]
# DBSCAN(eps=0.6, min_samples=10): Found  2 clusters, noise= 0.59%, cluster_sizes= [(-1, 87), (0, 9176), (1, 5425)].
# DBSCAN(eps=0.6, min_samples=12): Found  2 clusters, noise= 0.60%, cluster_sizes= [(-1, 88), (0, 9176), (1, 5424)]
# DBSCAN(eps=0.6, min_samples=13): Found  2 clusters, noise= 0.61%, cluster_sizes= [(-1, 90), (0, 9175), (1, 5423)].
# DBSCAN(eps=0.6, min_samples=15): Found  2 clusters, noise= 0.65%, cluster_sizes= [(-1, 96), (0, 9171), (1, 5421)]
# DBSCAN(eps=0.6, min_samples=16): Found  2 clusters, noise= 0.67%, cluster_sizes= [(-1, 98), (0, 9170), (1, 5420)]..
# DBSCAN(eps=0.6, min_samples=19): Found  2 clusters, noise= 0.67%, cluster_sizes= [(-1, 99), (0, 9170), (1, 5419)]
# DBSCAN(eps=0.6, min_samples=20): Found  2 clusters, noise= 0.69%, cluster_sizes= [(-1, 101), (0, 9169), (1, 5418)]
# DBSCAN(eps=0.7, min_samples= 3): Found  4 clusters, noise= 0.09%, cluster_sizes= [(-1, 13), (0, 9212), (1, 5451), (2, 7), (3, 5)]
# DBSCAN(eps=0.7, min_samples= 4): Found  4 clusters, noise= 0.10%, cluster_sizes= [(-1, 15), (0, 9212), (1, 5449), (2, 7), (3, 5)]
# DBSCAN(eps=0.7, min_samples= 5): Found  4 clusters, noise= 0.14%, cluster_sizes= [(-1, 21), (0, 9207), (1, 5449), (2, 6), (3, 5)]
# DBSCAN(eps=0.7, min_samples= 6): Found  2 clusters, noise= 0.22%, cluster_sizes= [(-1, 32), (0, 9207), (1, 5449)].
# DBSCAN(eps=0.7, min_samples= 8): Found  2 clusters, noise= 0.22%, cluster_sizes= [(-1, 33), (0, 9206), (1, 5449)]
# DBSCAN(eps=0.7, min_samples= 9): Found  2 clusters, noise= 0.26%, cluster_sizes= [(-1, 38), (0, 9206), (1, 5444)]..
# DBSCAN(eps=0.7, min_samples=12): Found  2 clusters, noise= 0.27%, cluster_sizes= [(-1, 39), (0, 9205), (1, 5444)].
# DBSCAN(eps=0.7, min_samples=14): Found  2 clusters, noise= 0.28%, cluster_sizes= [(-1, 41), (0, 9203), (1, 5444)]
# DBSCAN(eps=0.7, min_samples=15): Found  2 clusters, noise= 0.30%, cluster_sizes= [(-1, 44), (0, 9200), (1, 5444)].
# DBSCAN(eps=0.7, min_samples=17): Found  2 clusters, noise= 0.31%, cluster_sizes= [(-1, 45), (0, 9200), (1, 5443)]
# DBSCAN(eps=0.7, min_samples=18): Found  2 clusters, noise= 0.31%, cluster_sizes= [(-1, 46), (0, 9200), (1, 5442)]
# DBSCAN(eps=0.7, min_samples=19): Found  2 clusters, noise= 0.32%, cluster_sizes= [(-1, 47), (0, 9200), (1, 5441)].
# DBSCAN(eps=0.8, min_samples= 3): Found  3 clusters, noise= 0.03%, cluster_sizes= [(-1, 4), (0, 9212), (1, 5465), (2, 7)].
# DBSCAN(eps=0.8, min_samples= 5): Found  3 clusters, noise= 0.05%, cluster_sizes= [(-1, 7), (0, 9212), (1, 5462), (2, 7)]
# DBSCAN(eps=0.8, min_samples= 6): Found  2 clusters, noise= 0.10%, cluster_sizes= [(-1, 14), (0, 9212), (1, 5462)].
# DBSCAN(eps=0.8, min_samples= 8): Found  2 clusters, noise= 0.10%, cluster_sizes= [(-1, 15), (0, 9212), (1, 5461)].
# DBSCAN(eps=0.8, min_samples=10): Found  2 clusters, noise= 0.13%, cluster_sizes= [(-1, 19), (0, 9212), (1, 5457)]...
# DBSCAN(eps=0.8, min_samples=14): Found  2 clusters, noise= 0.14%, cluster_sizes= [(-1, 21), (0, 9210), (1, 5457)]......CPU times: user 5min 16s, sys: 2.65 s, total: 5min 19s
# Wall time: 5min 19s

# %%
# %%time
#Take 3
print('Running a series of DBSCANs to find the best fitting parameters - eps between 0.9 and 1.1.')

clusters_last = []
for EPS in np.arange(0.9, 1.11, 0.1):
  for Min_Samples in range(3, 21):   # range of values for minimum number of samples - between 3 and 20
    dbscan = DBSCAN(eps=EPS, min_samples=Min_Samples)
    pred_dbscan = dbscan.fit_predict(X)

    clusters_this = [*zip(*np.unique(pred_dbscan, return_counts=True))]
    if (clusters_this == clusters_last): print(end='.')
    else: clusters_last = clusters_this; \
      print(f'\nDBSCAN(eps={dbscan.eps:0.1f}, min_samples={dbscan.min_samples:2}):',
        f'Found {max(pred_dbscan) + 1 :2} cluster' + ('s,' if max(pred_dbscan) else ', '),
        f'noise={len(pred_dbscan[pred_dbscan==-1]) / len(X) :6.2%},',
          'cluster_sizes=', clusters_this, end='')
# Out:
# Running a series of DBSCANs to find the best fitting parameters - eps between 0.9 and 1.1.
#
# DBSCAN(eps=0.9, min_samples= 3): Found  2 clusters, noise= 0.01%, cluster_sizes= [(-1, 1), (0, 9220), (1, 5467)]...
# DBSCAN(eps=0.9, min_samples= 7): Found  2 clusters, noise= 0.01%, cluster_sizes= [(-1, 2), (0, 9219), (1, 5467)].
# DBSCAN(eps=0.9, min_samples= 9): Found  2 clusters, noise= 0.03%, cluster_sizes= [(-1, 5), (0, 9216), (1, 5467)]..
# DBSCAN(eps=0.9, min_samples=12): Found  2 clusters, noise= 0.04%, cluster_sizes= [(-1, 6), (0, 9216), (1, 5466)]........
# DBSCAN(eps=1.0, min_samples= 3): Found  2 clusters, noise= 0.00%, cluster_sizes= [(0, 9220), (1, 5468)].................
# DBSCAN(eps=1.1, min_samples= 3): Found  1 cluster,  noise= 0.00%, cluster_sizes= [(0, 14688)].................CPU times: user 5min 51s, sys: 10.5 s, total: 6min 1s
# Wall time: 6min 1s

# %% [markdown]
# ### OK the "best fit" eps = 0.3  and min_samples=5

# %% [markdown]
# ## Findings: ...

# %%
# Advice on limits of K-means and hierarchical
#the main disadvantages of partitioning and hierarchical methods are: handling noise and getting bad results with finding clusters of nonspherical shape.

# %%
# Advice on selecting parameters for DBScan:
#""...
#According to a research made in 2017 by Schubert, Sander, et al, the desirable amount of noise will usually be between 1% and 30%. 
#Another insight from that research is that if one of the clusters contains many (20%-50%) points of the dataset, 
#it indicates that you should choose a smaller value for ε or to try another clustering method.
#..." source: Amit Shreiber, A Practical Guide to DBSCAN Method,  https://towardsdatascience.com/a-practical-guide-to-dbscan-method-d4ec5ab2bc99
